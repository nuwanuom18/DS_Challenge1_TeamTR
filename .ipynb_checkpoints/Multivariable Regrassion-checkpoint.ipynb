# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('CSE_DSIntro1_TRAIN.csv')
df
# Out:
#         Id  Column_1     Column_2     Column_3   Column_4   Column_5  \
# 0        1   77041.5  44471.03389  88955.41342  1602.4632  1787.3628
# 1        2   77120.0  44516.34682  89046.05288  1573.2480  2128.5120
# 2        3   77120.0  44516.34682  89046.05288  1789.1840  1511.5520
# 3        4   77117.5  44514.90373  89043.16628  1511.5030  1789.1260
# 4        5   77120.0  44516.34682  89046.05288  1974.2720  1696.6400
# ...    ...       ...          ...          ...        ...        ...
# 2495  2496   77117.5  44514.90373  89043.16628  1203.0330  2282.6780
# 2496  2497   77120.0  44516.34682  89046.05288   894.5920  1203.0720
# 2497  2498   77117.5  44514.90373  89043.16628  1789.1260  1604.0440
# 2498  2499   77117.5  44514.90373  89043.16628  1789.1260   524.3990
# 2499  2500   77120.0  44516.34682  89046.05288  1542.4000  1789.1840
#
#        Column_6   Column_7   Column_8   Column_9  ...  Column_69  Column_70  \
# ...

# %%
plt.scatter(df.Id,df.Column_1,color='red',marker='+')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=2500, step=1),
#  Index(['Id', 'Column_1', 'Column_2', 'Column_3', 'Column_4', 'Column_5',
#         'Column_6', 'Column_7', 'Column_8', 'Column_9', 'Column_10',
#         'Column_11', 'Column_12', 'Column_13', 'Column_14', 'Column_15',
#         'Column_16', 'Column_17', 'Column_18', 'Column_19', 'Column_20',
#         'Column_21', 'Column_22', 'Column_23', 'Column_24', 'Column_25',
#         'Column_26', 'Column_27', 'Column_28', 'Column_29', 'Column_30',
#         'Column_31', 'Column_32', 'Column_33', 'Column_34', 'Column_35',
#         'Column_36', 'Column_37', 'Column_38', 'Column_39', 'Column_40',
#         'Column_41', 'Column_42', 'Column_43', 'Column_44', 'Column_45',
#         'Column_46', 'Column_47', 'Column_48', 'Column_49', 'Column_50',
#         'Column_51', 'Column_52', 'Column_53', 'Column_54', 'Column_55',
#         'Column_56', 'Column_57', 'Column_58', 'Column_59', 'Column_60',
# ...

# %%
reg = linear_model.LinearRegression()
reg.fit(df.drop('Category',axis='columns'),df.Category)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.coef_
# Out:
# array([ 2.29446939e-03,  4.47383983e+02, -9.90886652e+03, -1.63320554e+03,
#        -2.68937436e-06, -8.59507437e-07, -3.69767631e-06, -1.63367188e-06,
#         3.33069906e-06, -4.85471153e-06,  4.48680801e-06,  4.21175345e-05,
#         5.99094125e-06, -3.02396188e-06, -5.95746468e-06, -3.98388556e-06,
#        -1.76863341e-06,  1.59848126e-05, -3.12863608e-06,  2.50355227e-06,
#        -3.74739443e-06,  6.61971433e-06,  6.15114821e-06, -2.32801892e-06,
#        -2.61638161e-06, -4.75713438e-06, -2.32652098e-06, -4.42501391e-06,
#        -4.78926756e-06,  5.18805064e-06, -7.43929173e-05,  6.89291278e-06,
#        -3.14112276e-06, -2.71437267e-06,  2.11669317e-07, -2.90243224e-06,
#         1.54231259e-07, -4.35968650e-06,  1.33800449e-06,  3.21785001e-06,
#        -1.42249144e-06, -3.45615194e-06, -1.86984391e-06,  3.05068397e-07,
#         2.31181275e-06, -1.38580299e-06,  8.86154396e-07, -1.09276630e-06,
# ...

# %%
reg.intercept_
# Out:
# 14907.728887571395

# %%
array = df.values.tolist()[2495:2498]
x = np.array(array)
x.astype(int)
# Out:
# array([[  2496,  77117,  44514,  89043,   1203,   2282,   1542,   1758,
#           1850,   1295,   1172,   1418,   1573,    370,    493,   1511,
#            771,   2005,   1604,    524,   1388,   1017,   1079,   1943,
#            555,   1110,   1141,   1326,   1233,    431,    586,   1727,
#           1264,   1819,    863,    832,   1048,    740,    987,    956,
#            802,    709,    154,    678,    462,    894,    308,    647,
#            616,    401,    339,    246,     61,     30,   4007,     32,
#         308470,  10000,  63699,      1,      0,      1,  63689,      1,
#              0,      1,     11,     42,     33,     22,      2,   2021,
#             11,     42,     33,     22,      2,   2021,      1],
#        [  2497,  77120,  44516,  89046,    894,   1203,   1079,   1480,
#           1449,   1604,    987,   1264,   1388,    925,   1542,   1634,
#           1141,   1511,   1233,   1048,   1017,    863,   1326,   1172,
# ...

# %%
reg.predict([[  2496,  77117,  44514,  89043,   1203,   2282,   1542,   1758,
          1850,   1295,   1172,   1418,   1573,    370,    493,   1511,
           771,   2005,   1604,    524,   1388,   1017,   1079,   1943,
           555,   1110,   1141,   1326,   1233,    431,    586,   1727,
          1264,   1819,    863,    832,   1048,    740,    987,    956,
           802,    709,    154,    678,    462,    894,    308,    647,
           616,    401,    339,    246,     61,     30,   4007,     32,
        308470,  10000,  63699,      1,      0,      1,  63689,      1,
             0,      1,     11,     42,     33,     22,      2,   2021,
            11,     42,     33,     22,      2,   2021],
       [  2497,  77120,  44516,  89046,    894,   1203,   1079,   1480,
          1449,   1604,    987,   1264,   1388,    925,   1542,   1634,
          1141,   1511,   1233,   1048,   1017,    863,   1326,   1172,
          1357,   1295,   1419,    956,   1110,    277,    616,    308,
           832,    771,    802,    524,    709,    431,    493,    401,
           586,    740,    555,    647,    462,    678,    215,    370,
           246,    185,    123,    154,     92,     61,   3015,     32,
        308480,  10000,  63691,      1,      0,      1,  63696,      1,
             0,      1,     11,     42,     34,     22,      2,   2021,
            11,     42,     34,     22,      2,   2021],
       [  2498,  77117,  44514,  89043,   1789,   1604,   1326,   1418,
          1542,   1511,   1264,   1048,   1110,   1480,   1573,    956,
          1079,   1295,   1233,   1141,   1172,    555,    925,    493,
           987,   1449,   1017,   1203,    709,    462,    863,    740,
           524,    832,    647,    894,    802,    771,    678,    586,
           616,    370,    431,    277,    401,    308,    215,    339,
           185,    246,    154,    123,     92,     61,   2451,     32,
        308470,  10000,  63690,      1,      0,      1,  63695,      1,
             0,      1,     11,     42,     34,     22,      2,   2021,
            11,     42,     34,     22,      2,   2021]])
# Out:
# array([14452.97742165,  8973.08394864, 14452.8401667 ])
